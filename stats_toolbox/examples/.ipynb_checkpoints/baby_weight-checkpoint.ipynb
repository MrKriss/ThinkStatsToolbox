# %% [markdown]
# ## Setup

# %%
# Imports
import os
import sys
import pandas as pd
import seaborn as sb

# Custom Imports
sys.path.insert(0, '../../')
import stats_toolbox as st
from stats_toolbox.utils.data_loaders import load_fem_preg_2002

# Graphics setup 
# %pylab inline --no-import-all
sb.set_context('notebook', font_scale=1.5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Load Data

# %%
# Load and Clean Data
df = load_fem_preg_2002('../data')
full_term = df[df['prglngth'] >= 37]
weights = df.birthwgt_kg.dropna()

# %% [markdown]
# ## Histograms

# %%
# %matplotlib inline

# %%
H = st.Hist(df.birthwgt_kg, label='Birth Weight')

# %% [markdown]
# When plotting, the following keyword arguments can be passed to configure the plot once it has been generated:
#
# * `title`, `xlabel`, `ylabel`, `xscale`, `yscale`, `xticks`, `yticks`, `axis`, `xlim`, `ylim`, `legend`
#
# These all call the appropriate method from pyplot to alter the plot with the values passed in. e.g.

# %%
H.plot(title='My First Histogram', xlabel='Wieght (lb)', legend=True)

# %%
By default the plotting method used is pyplot.bar to plot each data points frequency.

# %% [markdown]
# Note that the apparent pattern in the bars above is due to the plot rendering itself (lots of bars very close together), not the underlying data. Zooming in to the plot shows this to be the case.

# %% [markdown]
# To be able to parse in the number of bins, we need to use plt.hist instead of plt.bar. to do this pass in `mpl_hist=True`. Additional keywords are then parsed to pyplot.hist instead of pyplot.bar

# %%
H.plot(mpl_hist=1, bins=20, histtype='stepfilled', alpha=0.7, 
      title='My Second Histogram', xlabel='Wieght (lb)', legend=True)

# %%
H.items()
# Out:
# dict_items([(34.329999999999998, 25), (29.66, 44), (33.579999999999998, 21), (38.25, 11), (10.33, 1), (11.75, 2), (36.159999999999997, 9), (13.66, 5), (14.91, 14), (15.83, 25), (16.829999999999998, 36), (17.829999999999998, 62), (18.079999999999998, 58), (19.41, 61), (20.75, 76), (21.16, 58), (22.079999999999998, 64), (23.16, 76), (24.16, 63), (25.25, 69), (26.16, 69), (27.16, 62), (28.25, 45), (29.25, 54), (30.579999999999998, 55), (31.5, 38), (32.659999999999997, 45), (33.329999999999998, 27), (34.659999999999997, 26), (35.25, 26), (36.409999999999997, 14), (37.329999999999998, 16), (38.75, 6), (39.159999999999997, 5), (40.829999999999998, 4), (41.25, 6), (42.079999999999998, 2), (43.25, 4), (44.079999999999998, 1), (27.829999999999998, 53), (27.91, 58), (40.079999999999998, 2), (25.91, 56), (29.829999999999998, 47), (14.0, 5), (10.91, 1), (39.409999999999997, 2), (36.829999999999998, 7), (39.659999999999997, 2), (22.16, 57), (19.5, 81), (12.66, 2), (32.0, 38), (21.329999999999998, 77), (25.66, 64), (28.41, 39), (13.91, 5), (19.16, 70), (14.75, 11), (14.58, 10), (15.75, 29), (37.159999999999997, 13), (16.91, 40), (17.75, 58), (16.329999999999998, 40), (17.41, 65), (29.91, 49), (18.579999999999998, 80), (19.079999999999998, 69), (18.25, 71), (24.329999999999998, 64), (20.579999999999998, 71), (20.41, 82), (38.579999999999998, 4), (26.329999